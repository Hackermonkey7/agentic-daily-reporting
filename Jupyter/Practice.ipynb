# %% [markdown]
# ##MSBA Bootcamp

# %%
#string[start:stop:step]
#// -> integer division
a=3
b=4
c = (a**2 + b**2)**0.5
print(c)
# Out:
# 5.0

# %%
num1,num2= input("Inital value of num1,num1: ").split()
num1 = int(num1)
num2 = int(num2)

# %%
#print the greatest among three numbers
a,b,c= int(input("Which is largest among the three numbers")).split()
largest_num=c
if a>=b>c:
    largest_num=a
    print(largest_num)
elif b>=a>c:
    largest_num=b
    print(largest_num)
else:
    largest_num=c
    print(largest_num)

# %%
# %pip install numpy
# Out:
# 90671.78s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('/Users/utkarshtyagi/Documents/VSC/Dataset/occupation.csv')
print(df.head())
# Print first 25 rows
print(df.head(25))
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213
#     user_id  age gender     occupation zip_code
# 0         1   24      M     technician    85711
# 1         2   53      F          other    94043
# 2         3   23      M         writer    32067
# 3         4   24      M     technician    43537
# 4         5   33      F          other    15213
# 5         6   42      M      executive    98101
# 6         7   57      M  administrator    91344
# 7         8   36      M  administrator    05201
# 8         9   29      M        student    01002
# 9        10   53      M         lawyer    90703
# 10       11   39      F          other    30329
# 11       12   28      F          other    06405
# 12       13   47      M       educator    29206
# ...

# %%
# %pip install seaborn
# Out:
# 93252.99s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 18.9 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 22.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 30.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [seaborn]m7/8 [seaborn]ib]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install matplotlib
# Out:
# 93278.06s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('/Users/utkarshtyagi/Documents/VSC/Dataset/Forbes2000.csv', encoding='latin1')
print(df.head())
# Print first 25 rows
print(df.head(25))
# Out:
#    Unnamed: 0  rank                 name         country  \
# 0           1     1            Citigroup   United States
# 1           2     2     General Electric   United States
# 2           3     3  American Intl Group   United States
# 3           4     4           ExxonMobil   United States
# 4           5     5                   BP  United Kingdom
#
#                category   sales  profits   assets  marketvalue
# 0               Banking   94.71    17.85  1264.03       255.30
# 1         Conglomerates  134.19    15.59   626.93       328.54
# 2             Insurance   76.66     6.46   647.66       194.87
# 3  Oil & gas operations  222.88    20.96   166.99       277.02
# 4  Oil & gas operations  232.57    10.27   177.57       173.54
#     Unnamed: 0  rank                     name                      country  \
# 0            1     1                Citigroup                United States
# 1            2     2         General Electric                United States
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('/Users/utkarshtyagi/Documents/VSC/Dataset/Forbes2000.csv', encoding='latin1')
print(df.head())
# Print first 25 rows
print(df.head(25))
#data quallity report
Test_report= df.describe()
print(Test_report)
# Out:
#    Unnamed: 0  rank                 name         country  \
# 0           1     1            Citigroup   United States
# 1           2     2     General Electric   United States
# 2           3     3  American Intl Group   United States
# 3           4     4           ExxonMobil   United States
# 4           5     5                   BP  United Kingdom
#
#                category   sales  profits   assets  marketvalue
# 0               Banking   94.71    17.85  1264.03       255.30
# 1         Conglomerates  134.19    15.59   626.93       328.54
# 2             Insurance   76.66     6.46   647.66       194.87
# 3  Oil & gas operations  222.88    20.96   166.99       277.02
# 4  Oil & gas operations  232.57    10.27   177.57       173.54
#     Unnamed: 0  rank                     name                      country  \
# 0            1     1                Citigroup                United States
# 1            2     2         General Electric                United States
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('/Users/utkarshtyagi/Documents/VSC/Dataset/Forbes2000.csv', encoding='latin1')
print(df.head())
# Print first 25 rows
print(df.head(25))
#data quallity report
Test_report= df.describe()
print(Test_report)
#drop rows with missing values
Test_report.dropna(inplace=True)
print(Test_report)
